# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmisaha/sharmii/blob/main/Topic_Modelling_with_Haemophilia_Data_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing the Necessary Libraries:

# %%
# !pip install tweet-preprocessor
# !pip install bertopic
# !pip install emoji
# Out:
# Collecting tweet-preprocessor
#   Downloading tweet_preprocessor-0.6.0-py3-none-any.whl (27 kB)
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.6.0
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 9.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.35.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu121)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.4.1->bertopic) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, umap-learn
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039291 sha256=3bea0926db4a7a6f143906c071030503bc419138e4c9e784e89a2d068b18d40c
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=e4ecfb1e3de292da5e4f2a9a9ec54c0311c8742508e133ae44dd33bba3b8b36e
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built hdbscan umap-learn
# Installing collected packages: cython, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.8
#     Uninstalling Cython-3.0.8:
#       Successfully uninstalled Cython-3.0.8
# Successfully installed bertopic-0.16.0 cython-0.29.37 hdbscan-0.8.33 pynndescent-0.5.11 sentence-transformers-2.3.1 umap-learn-0.5.5

# %% [markdown]
# # Importing The Necessary Libraries:

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# import tweet preprocessor
import preprocessor as p

import time
import nltk
import gensim
import re
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from bertopic import BERTopic
#from sklearn.decomposition import PCA
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
#from sklearn.cluster import KMeans
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel
from bertopic.vectorizers import ClassTfidfTransformer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading The Data:

# %%
df = pd.read_csv("/content/my_data.csv")
df
# Out:
#        Unnamed: 0      tweet_id  external_twitter_id  \
# 0               0  1.030258e+06         1.680000e+18
# 1               1  1.030186e+06         1.680000e+18
# 2               2  1.030263e+06         1.680000e+18
# 3               3  1.030274e+06         1.680000e+18
# 4               4  1.030288e+06         1.680000e+18
# ...           ...           ...                  ...
# 29798       29798  1.683840e+18                  NaN
# 29799       29799  1.683940e+18                  NaN
# 29800       29800  1.683860e+18                  NaN
# 29801       29801  1.683920e+18                  NaN
# 29802       29802  1.683830e+18                  NaN
#
#                                                     text     author_id  \
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ...  9.050000e+17
# 1      Roche Drops Hemophilia A Candidate, Prepares f...  7.638583e+07
# 2      Roche moves one Spark hemophilia gene therapy ...  1.480000e+18
# 3      On #WorldHepatitisDay we put middle finger up ...  1.150000e+18
# 4      One of our newest internship programs, launche...  2.112887e+08
# ...                                                  ...           ...
# 29798  Hear more from Mosi Williams, Pys.D, on the la...  1.480000e+18
# 29799  Was discussing hemophilia with an intelligent,...  2.760856e+08
# 29800  The affected &amp; infected have waited decade...  1.104181e+08
# 29801  @MohmdBio Sickle cell anemia, Thalassemia, Hem...  1.180000e+18
# 29802  Save the date to “tee up for a cure” on Monday...  4.867600e+08
#
#              created_at lang  referenced_tweets_type  referenced_tweets_id  \
# 0      28-07-2023 08:18   en                       0          0.000000e+00
# 1      27-07-2023 15:51   en                       0          0.000000e+00
# 2      28-07-2023 06:34   en                       0          0.000000e+00
# 3      28-07-2023 00:27   en                       0          0.000000e+00
# 4      27-07-2023 20:13   en                       3          1.680000e+18
# ...                 ...  ...                     ...                   ...
# 29798  25-07-2023 14:00   en                       0          0.000000e+00
# 29799  25-07-2023 20:32   en                       0          0.000000e+00
# 29800  25-07-2023 15:25   en                       3          1.680000e+18
# 29801  25-07-2023 19:13   en                       2          1.680000e+18
# 29802  25-07-2023 13:38   en                       0          0.000000e+00
#
#       infos  association_tweet_id  association_scope_id
# 0        {}          1.030258e+06                    10
# 1        {}          1.030186e+06                    10
# 2        {}          1.030263e+06                    10
# 3        {}          1.030274e+06                    10
# 4        {}          1.030288e+06                    10
# ...     ...                   ...                   ...
# 29798    {}          1.683840e+18                    10
# 29799    {}          1.683940e+18                    10
# 29800    {}          1.683860e+18                    10
# 29801    {}          1.683920e+18                    10
# 29802    {}          1.683830e+18                    10
#
# [29803 rows x 12 columns]

# %% [markdown]
# ### Let's filter the data with the columns that are important for our use case:

# %%
columns_to_keep = ['author_id','tweet_id','text','created_at']

new_df = df[columns_to_keep]
new_df
# Out:
#           author_id      tweet_id  \
# 0      9.050000e+17  1.030258e+06
# 1      7.638583e+07  1.030186e+06
# 2      1.480000e+18  1.030263e+06
# 3      1.150000e+18  1.030274e+06
# 4      2.112887e+08  1.030288e+06
# ...             ...           ...
# 29798  1.480000e+18  1.683840e+18
# 29799  2.760856e+08  1.683940e+18
# 29800  1.104181e+08  1.683860e+18
# 29801  1.180000e+18  1.683920e+18
# 29802  4.867600e+08  1.683830e+18
#
#                                                     text        created_at
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ...  28-07-2023 08:18
# 1      Roche Drops Hemophilia A Candidate, Prepares f...  27-07-2023 15:51
# 2      Roche moves one Spark hemophilia gene therapy ...  28-07-2023 06:34
# 3      On #WorldHepatitisDay we put middle finger up ...  28-07-2023 00:27
# 4      One of our newest internship programs, launche...  27-07-2023 20:13
# ...                                                  ...               ...
# 29798  Hear more from Mosi Williams, Pys.D, on the la...  25-07-2023 14:00
# 29799  Was discussing hemophilia with an intelligent,...  25-07-2023 20:32
# 29800  The affected &amp; infected have waited decade...  25-07-2023 15:25
# 29801  @MohmdBio Sickle cell anemia, Thalassemia, Hem...  25-07-2023 19:13
# 29802  Save the date to “tee up for a cure” on Monday...  25-07-2023 13:38
#
# [29803 rows x 4 columns]

# %% [markdown]
# ### Checking if there is any null values:

# %%
new_df.isnull().sum()
# Out:
# author_id     0
# tweet_id      0
# text          0
# created_at    0
# dtype: int64

# %% [markdown]
# ### No null values are present here.
#
# ### Now we need to separate the 'created_at' column into 'date', 'time', and the 'day_of week'.

# %%
print(new_df['created_at'].dtype)
# Out:
# object

# %%
import pandas as pd
# Assuming 'created_at' is in string format, convert it to datetime
new_df['created_at'] = pd.to_datetime(new_df['created_at'], errors = 'coerce')


# Create a new column for the date, time, and day
new_df['date'] = new_df['created_at'].dt.date
new_df['time'] = new_df['created_at'].dt.time
new_df['day_of_week'] = new_df['created_at'].dt.day_name()
# Display the updated DataFrame
new_df
# Out:
#           author_id      tweet_id  \
# 0      9.050000e+17  1.030258e+06
# 1      7.638583e+07  1.030186e+06
# 2      1.480000e+18  1.030263e+06
# 3      1.150000e+18  1.030274e+06
# 4      2.112887e+08  1.030288e+06
# ...             ...           ...
# 29798  1.480000e+18  1.683840e+18
# 29799  2.760856e+08  1.683940e+18
# 29800  1.104181e+08  1.683860e+18
# 29801  1.180000e+18  1.683920e+18
# 29802  4.867600e+08  1.683830e+18
#
#                                                     text          created_at  \
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ... 2023-07-28 08:18:00
# 1      Roche Drops Hemophilia A Candidate, Prepares f... 2023-07-27 15:51:00
# 2      Roche moves one Spark hemophilia gene therapy ... 2023-07-28 06:34:00
# 3      On #WorldHepatitisDay we put middle finger up ... 2023-07-28 00:27:00
# 4      One of our newest internship programs, launche... 2023-07-27 20:13:00
# ...                                                  ...                 ...
# 29798  Hear more from Mosi Williams, Pys.D, on the la... 2023-07-25 14:00:00
# 29799  Was discussing hemophilia with an intelligent,... 2023-07-25 20:32:00
# 29800  The affected &amp; infected have waited decade... 2023-07-25 15:25:00
# 29801  @MohmdBio Sickle cell anemia, Thalassemia, Hem... 2023-07-25 19:13:00
# 29802  Save the date to “tee up for a cure” on Monday... 2023-07-25 13:38:00
#
#              date      time day_of_week
# 0      2023-07-28  08:18:00      Friday
# 1      2023-07-27  15:51:00    Thursday
# 2      2023-07-28  06:34:00      Friday
# 3      2023-07-28  00:27:00      Friday
# 4      2023-07-27  20:13:00    Thursday
# ...           ...       ...         ...
# 29798  2023-07-25  14:00:00     Tuesday
# 29799  2023-07-25  20:32:00     Tuesday
# 29800  2023-07-25  15:25:00     Tuesday
# 29801  2023-07-25  19:13:00     Tuesday
# 29802  2023-07-25  13:38:00     Tuesday
#
# [29803 rows x 7 columns]

# %%
new_df.isnull().sum()
# Out:
# author_id      0
# tweet_id       0
# text           0
# created_at     0
# date           0
# time           0
# day_of_week    0
# dtype: int64

# %% [markdown]
# 1.   Check whether hashtag is present or not.
# 2.   Count the Number of hashtags
# 3.   List the hashtags present in the tweet

# %%
new_df['has_hashtags'] = new_df['text'].str.contains('#', case = False)

#Count nummber of hashtags
new_df['num_hashtags'] = new_df['text'].apply(lambda x: len([ c for c in x if c =='#']))
new_df.head()
# Out:
#       author_id   tweet_id                                               text  \
# 0  9.050000e+17  1030258.0  3 peaks Challenge #AxioActive💪\n\nOn the 12th ...
# 1  7.638583e+07  1030186.0  Roche Drops Hemophilia A Candidate, Prepares f...
# 2  1.480000e+18  1030263.0  Roche moves one Spark hemophilia gene therapy ...
# 3  1.150000e+18  1030274.0  On #WorldHepatitisDay we put middle finger up ...
# 4  2.112887e+08  1030288.0  One of our newest internship programs, launche...
#
#            created_at        date      time day_of_week  has_hashtags  \
# 0 2023-07-28 08:18:00  2023-07-28  08:18:00      Friday          True
# 1 2023-07-27 15:51:00  2023-07-27  15:51:00    Thursday         False
# 2 2023-07-28 06:34:00  2023-07-28  06:34:00      Friday         False
# 3 2023-07-28 00:27:00  2023-07-28  00:27:00      Friday          True
# 4 2023-07-27 20:13:00  2023-07-27  20:13:00    Thursday          True
#
#    num_hashtags
# 0             1
# 1             0
# 2             0
# 3             9
# 4             3

# %%
new_df['list_of_hashtags'] = new_df['text'].apply(lambda x: [word for word in x.split() if word.startswith("#")])
new_df
# Out:
#           author_id      tweet_id  \
# 0      9.050000e+17  1.030258e+06
# 1      7.638583e+07  1.030186e+06
# 2      1.480000e+18  1.030263e+06
# 3      1.150000e+18  1.030274e+06
# 4      2.112887e+08  1.030288e+06
# ...             ...           ...
# 29798  1.480000e+18  1.683840e+18
# 29799  2.760856e+08  1.683940e+18
# 29800  1.104181e+08  1.683860e+18
# 29801  1.180000e+18  1.683920e+18
# 29802  4.867600e+08  1.683830e+18
#
#                                                     text          created_at  \
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ... 2023-07-28 08:18:00
# 1      Roche Drops Hemophilia A Candidate, Prepares f... 2023-07-27 15:51:00
# 2      Roche moves one Spark hemophilia gene therapy ... 2023-07-28 06:34:00
# 3      On #WorldHepatitisDay we put middle finger up ... 2023-07-28 00:27:00
# 4      One of our newest internship programs, launche... 2023-07-27 20:13:00
# ...                                                  ...                 ...
# 29798  Hear more from Mosi Williams, Pys.D, on the la... 2023-07-25 14:00:00
# 29799  Was discussing hemophilia with an intelligent,... 2023-07-25 20:32:00
# 29800  The affected &amp; infected have waited decade... 2023-07-25 15:25:00
# 29801  @MohmdBio Sickle cell anemia, Thalassemia, Hem... 2023-07-25 19:13:00
# 29802  Save the date to “tee up for a cure” on Monday... 2023-07-25 13:38:00
#
#              date      time day_of_week  has_hashtags  num_hashtags  \
# 0      2023-07-28  08:18:00      Friday          True             1
# 1      2023-07-27  15:51:00    Thursday         False             0
# 2      2023-07-28  06:34:00      Friday         False             0
# 3      2023-07-28  00:27:00      Friday          True             9
# 4      2023-07-27  20:13:00    Thursday          True             3
# ...           ...       ...         ...           ...           ...
# 29798  2023-07-25  14:00:00     Tuesday          True             2
# 29799  2023-07-25  20:32:00     Tuesday         False             0
# 29800  2023-07-25  15:25:00     Tuesday          True             3
# 29801  2023-07-25  19:13:00     Tuesday         False             0
# 29802  2023-07-25  13:38:00     Tuesday         False             0
#
#                                         list_of_hashtags
# 0                                         [#AxioActive💪]
# 1                                                     []
# 2                                                     []
# 3      [#WorldHepatitisDay, #Australia’s, #health, #c...
# 4      [#SpecialtyPharmacy., #NationalInternDay, #AMC...
# ...                                                  ...
# 29798                             [#hemophilia, #GHRpod]
# 29799                                                 []
# 29800                        [#haemophilia, #HIV, #HEPC]
# 29801                                                 []
# 29802                                                 []
#
# [29803 rows x 10 columns]

# %%
hashtag_counts = new_df['has_hashtags'].value_counts()
hashtag_counts
# Out:
# False    16165
# True     13638
# Name: has_hashtags, dtype: int64

# %% [markdown]
# 1.   Check whether emoji is present or not.
# 2.   Count the Number of emoji
# 3.   List the emoji present in the tweet

# %%
new_df['num_of_emoji'] = new_df['emojis_list'].apply(len)
new_df.head()
# Out:
#       author_id   tweet_id                                               text  \
# 0  9.050000e+17  1030258.0  3 peaks Challenge #AxioActive💪\n\nOn the 12th ...
# 1  7.638583e+07  1030186.0  Roche Drops Hemophilia A Candidate, Prepares f...
# 2  1.480000e+18  1030263.0  Roche moves one Spark hemophilia gene therapy ...
# 3  1.150000e+18  1030274.0  On #WorldHepatitisDay we put middle finger up ...
# 4  2.112887e+08  1030288.0  One of our newest internship programs, launche...
#
#            created_at        date      time day_of_week  has_hashtags  \
# 0 2023-07-28 08:18:00  2023-07-28  08:18:00      Friday          True
# 1 2023-07-27 15:51:00  2023-07-27  15:51:00    Thursday         False
# 2 2023-07-28 06:34:00  2023-07-28  06:34:00      Friday         False
# 3 2023-07-28 00:27:00  2023-07-28  00:27:00      Friday          True
# 4 2023-07-27 20:13:00  2023-07-27  20:13:00    Thursday          True
#
#    num_hashtags                                   list_of_hashtags  \
# 0             1                                     [#AxioActive💪]
# 1             0                                                 []
# 2             0                                                 []
# 3             9  [#WorldHepatitisDay, #Australia’s, #health, #c...
# 4             3  [#SpecialtyPharmacy., #NationalInternDay, #AMC...
#
#    has_emojis emojis_list  num_of_emoji
# 0        True         [💪]             1
# 1       False          []             0
# 2       False          []             0
# 3       False          []             0
# 4        True         [🤩]             1

# %% [markdown]
# ## Count The Number of words present in the tweet:

# %%
# count the number of words
new_df['num_words'] = new_df['text'].apply(lambda x: len(x.split()))

# %%
new_df.head()
# Out:
#       author_id   tweet_id                                               text  \
# 0  9.050000e+17  1030258.0  3 peaks Challenge #AxioActive💪\n\nOn the 12th ...
# 1  7.638583e+07  1030186.0  Roche Drops Hemophilia A Candidate, Prepares f...
# 2  1.480000e+18  1030263.0  Roche moves one Spark hemophilia gene therapy ...
# 3  1.150000e+18  1030274.0  On #WorldHepatitisDay we put middle finger up ...
# 4  2.112887e+08  1030288.0  One of our newest internship programs, launche...
#
#            created_at        date      time day_of_week  has_hashtags  \
# 0 2023-07-28 08:18:00  2023-07-28  08:18:00      Friday          True
# 1 2023-07-27 15:51:00  2023-07-27  15:51:00    Thursday         False
# 2 2023-07-28 06:34:00  2023-07-28  06:34:00      Friday         False
# 3 2023-07-28 00:27:00  2023-07-28  00:27:00      Friday          True
# 4 2023-07-27 20:13:00  2023-07-27  20:13:00    Thursday          True
#
#    num_hashtags                                   list_of_hashtags  \
# 0             1                                     [#AxioActive💪]
# 1             0                                                 []
# 2             0                                                 []
# 3             9  [#WorldHepatitisDay, #Australia’s, #health, #c...
# 4             3  [#SpecialtyPharmacy., #NationalInternDay, #AMC...
#
#    has_emojis emojis_list  num_of_emoji  num_words
# 0        True         [💪]             1         41
# 1       False          []             0         13
# 2       False          []             0         12
# 3       False          []             0         37
# 4        True         [🤩]             1         26

# %% [markdown]
# ## Count words After removing stopword:

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Function to count words after removing stopwords
def count_words_without_stopwords(text):
  stop_words = set(stopwords.words('english'))
  words = [word for word in text.split() if word.lower() not in stop_words]
  return len(words)

new_df['num_words_without_stopwords'] = new_df['text'].apply(count_words_without_stopwords)
new_df.head()
# Out:
#       author_id   tweet_id                                               text  \
# 0  9.050000e+17  1030258.0  3 peaks Challenge #AxioActive💪\n\nOn the 12th ...
# 1  7.638583e+07  1030186.0  Roche Drops Hemophilia A Candidate, Prepares f...
# 2  1.480000e+18  1030263.0  Roche moves one Spark hemophilia gene therapy ...
# 3  1.150000e+18  1030274.0  On #WorldHepatitisDay we put middle finger up ...
# 4  2.112887e+08  1030288.0  One of our newest internship programs, launche...
#
#            created_at        date      time day_of_week  has_hashtags  \
# 0 2023-07-28 08:18:00  2023-07-28  08:18:00      Friday          True
# 1 2023-07-27 15:51:00  2023-07-27  15:51:00    Thursday         False
# 2 2023-07-28 06:34:00  2023-07-28  06:34:00      Friday         False
# 3 2023-07-28 00:27:00  2023-07-28  00:27:00      Friday          True
# 4 2023-07-27 20:13:00  2023-07-27  20:13:00    Thursday          True
#
#    num_hashtags                                   list_of_hashtags  \
# 0             1                                     [#AxioActive💪]
# 1             0                                                 []
# 2             0                                                 []
# 3             9  [#WorldHepatitisDay, #Australia’s, #health, #c...
# 4             3  [#SpecialtyPharmacy., #NationalInternDay, #AMC...
#
#    has_emojis emojis_list  num_of_emoji  num_words  \
# 0        True         [💪]             1         41
# 1       False          []             0         13
# 2       False          []             0         12
# 3       False          []             0         37
# 4        True         [🤩]             1         26
#
#    num_words_without_stopwords
# 0                           26
# 1                            9
# 2                           11
# 3                           23
# 4                           18

# %% [markdown]
# ## Calculate the stopwprd ration:

# %%
# create a new column with stopword ratio
new_df['stopword_ratio'] = new_df['num_words_without_stopwords']/new_df['num_words']
new_df.head()
# Out:
#       author_id   tweet_id                                               text  \
# 0  9.050000e+17  1030258.0  3 peaks Challenge #AxioActive💪\n\nOn the 12th ...
# 1  7.638583e+07  1030186.0  Roche Drops Hemophilia A Candidate, Prepares f...
# 2  1.480000e+18  1030263.0  Roche moves one Spark hemophilia gene therapy ...
# 3  1.150000e+18  1030274.0  On #WorldHepatitisDay we put middle finger up ...
# 4  2.112887e+08  1030288.0  One of our newest internship programs, launche...
#
#            created_at        date      time day_of_week  has_hashtags  \
# 0 2023-07-28 08:18:00  2023-07-28  08:18:00      Friday          True
# 1 2023-07-27 15:51:00  2023-07-27  15:51:00    Thursday         False
# 2 2023-07-28 06:34:00  2023-07-28  06:34:00      Friday         False
# 3 2023-07-28 00:27:00  2023-07-28  00:27:00      Friday          True
# 4 2023-07-27 20:13:00  2023-07-27  20:13:00    Thursday          True
#
#    num_hashtags                                   list_of_hashtags  \
# 0             1                                     [#AxioActive💪]
# 1             0                                                 []
# 2             0                                                 []
# 3             9  [#WorldHepatitisDay, #Australia’s, #health, #c...
# 4             3  [#SpecialtyPharmacy., #NationalInternDay, #AMC...
#
#    has_emojis emojis_list  num_of_emoji  num_words  \
# 0        True         [💪]             1         41
# 1       False          []             0         13
# 2       False          []             0         12
# 3       False          []             0         37
# 4        True         [🤩]             1         26
#
#    num_words_without_stopwords  stopword_ratio
# 0                           26        0.634146
# 1                            9        0.692308
# 2                           11        0.916667
# 3                           23        0.621622
# 4                           18        0.692308

# %% [markdown]
# ## Visualization:

# %%
# Plot the frequency of True and False values with annotations
fig, ax = plt.subplots()
bars = plt.bar(hashtag_counts.index.astype(str), hashtag_counts, color=['green', 'red'])

# Add annotations with value counts within the bars
for bar in bars:
  yval = bar.get_height()
  ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 1), ha='center', va='bottom')


plt.xlabel('Hashtags Presence (True or False)')
plt.ylabel('Frequency')
plt.title('Frequency of Hashtags Presence in Tweets')
plt.show()

# %%
emoji_counts = new_df['has_emojis'].value_counts()
emoji_counts
# Out:
# False    26122
# True      3681
# Name: has_emojis, dtype: int64

# %% [markdown]
# **Bar Plot for Emojis Count**

# %%
# Plot the frequency of True and False values with annotations
fig, ax = plt.subplots()
bars = plt.bar(emoji_counts.index.astype(str), emoji_counts, color=['green', 'red'])

# Add annotations with value counts within the bars
for bar in bars:
  yval = bar.get_height()
  ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 1), ha='center', va='bottom')


plt.xlabel('EMojis Presence (True or False)')
plt.ylabel('Frequency')
plt.title('Frequency of emojis Presence in Tweets')
plt.show()

# %% [markdown]
# **Frequency of Tweets on Each Day of the Week**

# %%
day_of_week_counts = new_df['day_of_week'].value_counts()

plt.bar(day_of_week_counts.index, day_of_week_counts, color = 'blue')
plt.xlabel('Day of the Week')
plt.ylabel('Frequency')
plt.title('Frequency of Tweets on Each Day of the Week')
plt.show()

# %%
day_of_week_counts
# Out:
# Monday       8115
# Tuesday      4623
# Thursday     3817
# Friday       3567
# Wednesday    3464
# Sunday       3224
# Saturday     2993
# Name: day_of_week, dtype: int64

# %%
# Find the highest number of hashtags and emojis
max_hashtags_author = new_df.loc[new_df['num_hashtags'].idxmax(), 'author_id']
max_hashtags_tweet = new_df.loc[new_df['num_hashtags'].idxmax(), 'tweet_id']
max_emojis_author = new_df.loc[new_df['emojis_list'].apply(len).idxmax(), 'author_id']
max_emojis_tweet = new_df.loc[new_df['emojis_list'].apply(len).idxmax(), 'tweet_id']

print(f"Highest number of hashtags by Author {max_hashtags_author} in Tweet {max_hashtags_tweet}")
print(f"Highest number of emojis by Author {max_emojis_author} in Tweet {max_emojis_tweet}")
# Out:
# Highest number of hashtags by Author 1.55e+18 in Tweet 168795.0
# Highest number of emojis by Author 1.4e+18 in Tweet 172011.0

# %% [markdown]
# ## Data Preprocessing:

# %%
my_frame = new_df.loc[:, ['author_id', 'tweet_id','text', 'created_at']]
my_frame
# Out:
#           author_id      tweet_id  \
# 0      9.050000e+17  1.030258e+06
# 1      7.638583e+07  1.030186e+06
# 2      1.480000e+18  1.030263e+06
# 3      1.150000e+18  1.030274e+06
# 4      2.112887e+08  1.030288e+06
# ...             ...           ...
# 29798  1.480000e+18  1.683840e+18
# 29799  2.760856e+08  1.683940e+18
# 29800  1.104181e+08  1.683860e+18
# 29801  1.180000e+18  1.683920e+18
# 29802  4.867600e+08  1.683830e+18
#
#                                                     text          created_at
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ... 2023-07-28 08:18:00
# 1      Roche Drops Hemophilia A Candidate, Prepares f... 2023-07-27 15:51:00
# 2      Roche moves one Spark hemophilia gene therapy ... 2023-07-28 06:34:00
# 3      On #WorldHepatitisDay we put middle finger up ... 2023-07-28 00:27:00
# 4      One of our newest internship programs, launche... 2023-07-27 20:13:00
# ...                                                  ...                 ...
# 29798  Hear more from Mosi Williams, Pys.D, on the la... 2023-07-25 14:00:00
# 29799  Was discussing hemophilia with an intelligent,... 2023-07-25 20:32:00
# 29800  The affected &amp; infected have waited decade... 2023-07-25 15:25:00
# 29801  @MohmdBio Sickle cell anemia, Thalassemia, Hem... 2023-07-25 19:13:00
# 29802  Save the date to “tee up for a cure” on Monday... 2023-07-25 13:38:00
#
# [29803 rows x 4 columns]

# %%
my_frame.isnull().sum()
# Out:
# author_id     0
# tweet_id      0
# text          0
# created_at    0
# dtype: int64

# %%
my_frame.shape
# Out:
# (29803, 4)

# %%
# Filter rows where the 'text' column does not contain both 'Hemophilia' and 'Haemophilia'
filtered_df = my_frame[(my_frame['text'].str.contains('Hemophilia', case=False) | my_frame['text'].str.contains('Haemophilia', case=False))]

# Select the specified columns
data_tweet = filtered_df[['author_id', 'tweet_id', 'text', 'created_at']]
data_tweet
# Out:
#           author_id      tweet_id  \
# 0      9.050000e+17  1.030258e+06
# 1      7.638583e+07  1.030186e+06
# 2      1.480000e+18  1.030263e+06
# 3      1.150000e+18  1.030274e+06
# 4      2.112887e+08  1.030288e+06
# ...             ...           ...
# 29798  1.480000e+18  1.683840e+18
# 29799  2.760856e+08  1.683940e+18
# 29800  1.104181e+08  1.683860e+18
# 29801  1.180000e+18  1.683920e+18
# 29802  4.867600e+08  1.683830e+18
#
#                                                     text          created_at
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ... 2023-07-28 08:18:00
# 1      Roche Drops Hemophilia A Candidate, Prepares f... 2023-07-27 15:51:00
# 2      Roche moves one Spark hemophilia gene therapy ... 2023-07-28 06:34:00
# 3      On #WorldHepatitisDay we put middle finger up ... 2023-07-28 00:27:00
# 4      One of our newest internship programs, launche... 2023-07-27 20:13:00
# ...                                                  ...                 ...
# 29798  Hear more from Mosi Williams, Pys.D, on the la... 2023-07-25 14:00:00
# 29799  Was discussing hemophilia with an intelligent,... 2023-07-25 20:32:00
# 29800  The affected &amp; infected have waited decade... 2023-07-25 15:25:00
# 29801  @MohmdBio Sickle cell anemia, Thalassemia, Hem... 2023-07-25 19:13:00
# 29802  Save the date to “tee up for a cure” on Monday... 2023-07-25 13:38:00
#
# [27396 rows x 4 columns]

# %%
data_tweet.isnull().sum()
# Out:
# author_id     0
# tweet_id      0
# text          0
# created_at    0
# dtype: int64

# %%
data_tweet.dtypes
# Out:
# author_id            float64
# tweet_id             float64
# text                  object
# created_at    datetime64[ns]
# dtype: object

# %%
# Customizing the preprocessor to exclude removing hashtags since they are valuable as a rich information
p.set_options(p.OPT.URL, p.OPT.EMOJI,p.OPT.MENTION,p.OPT.SMILEY,p.OPT.NUMBER )

data_tweet['new_text']  = data_tweet['text'].apply(lambda x: p.clean(str(x)) if pd.notna(x) else '')

# %%
data_tweet
# Out:
#           author_id      tweet_id  \
# 0      9.050000e+17  1.030258e+06
# 1      7.638583e+07  1.030186e+06
# 2      1.480000e+18  1.030263e+06
# 3      1.150000e+18  1.030274e+06
# 4      2.112887e+08  1.030288e+06
# ...             ...           ...
# 29798  1.480000e+18  1.683840e+18
# 29799  2.760856e+08  1.683940e+18
# 29800  1.104181e+08  1.683860e+18
# 29801  1.180000e+18  1.683920e+18
# 29802  4.867600e+08  1.683830e+18
#
#                                                     text          created_at  \
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ... 2023-07-28 08:18:00
# 1      Roche Drops Hemophilia A Candidate, Prepares f... 2023-07-27 15:51:00
# 2      Roche moves one Spark hemophilia gene therapy ... 2023-07-28 06:34:00
# 3      On #WorldHepatitisDay we put middle finger up ... 2023-07-28 00:27:00
# 4      One of our newest internship programs, launche... 2023-07-27 20:13:00
# ...                                                  ...                 ...
# 29798  Hear more from Mosi Williams, Pys.D, on the la... 2023-07-25 14:00:00
# 29799  Was discussing hemophilia with an intelligent,... 2023-07-25 20:32:00
# 29800  The affected &amp; infected have waited decade... 2023-07-25 15:25:00
# 29801  @MohmdBio Sickle cell anemia, Thalassemia, Hem... 2023-07-25 19:13:00
# 29802  Save the date to “tee up for a cure” on Monday... 2023-07-25 13:38:00
#
#                                                 new_text
# 0      peaks Challenge #AxioActive On the th of Augus...
# 1      Roche Drops Hemophilia A Candidate, Prepares f...
# 2      Roche moves one Spark hemophilia gene therapy ...
# 3      On #WorldHepatitisDay we put middle finger up ...
# 4      One of our newest internship programs, launche...
# ...                                                  ...
# 29798  Hear more from Mosi Williams, Pys.D, on the la...
# 29799  Was discussing hemophilia with an intelligent,...
# 29800  The affected &amp; infected have waited decade...
# 29801        Sickle cell anemia, Thalassemia, Hemophilia
# 29802  Save the date to tee up for a cure on Monday, ...
#
# [27396 rows x 5 columns]

# %%
data_tweet.isnull().sum()
# Out:
# author_id     0
# tweet_id      0
# text          0
# created_at    0
# new_text      0
# dtype: int64

# %%
#REMOVE ONLY THE '#'NOT THE WORD AFTER
def remove_hashtag_sign(text):
    text = re.sub(r'#', '', text)
    return text

data_tweet['new_text'] = data_tweet['new_text'].apply(lambda x:remove_hashtag_sign(x))

# %%
#Remove extra white spaces, punctuation and apply lower casing
data_tweet['new_text'] = data_tweet['new_text'].str.lower().str.replace('[^\w\s]',' ').str.replace('\s\s+', ' ')
data_tweet.head()
# Out:
#       author_id   tweet_id                                               text  \
# 0  9.050000e+17  1030258.0  3 peaks Challenge #AxioActive💪\n\nOn the 12th ...
# 1  7.638583e+07  1030186.0  Roche Drops Hemophilia A Candidate, Prepares f...
# 2  1.480000e+18  1030263.0  Roche moves one Spark hemophilia gene therapy ...
# 3  1.150000e+18  1030274.0  On #WorldHepatitisDay we put middle finger up ...
# 4  2.112887e+08  1030288.0  One of our newest internship programs, launche...
#
#            created_at                                           new_text
# 0 2023-07-28 08:18:00  peaks challenge axioactive on the th of august...
# 1 2023-07-27 15:51:00  roche drops hemophilia a candidate prepares fo...
# 2 2023-07-28 06:34:00  roche moves one spark hemophilia gene therapy ...
# 3 2023-07-28 00:27:00  on worldhepatitisday we put middle finger up t...
# 4 2023-07-27 20:13:00  one of our newest internship programs launched...

# %%
data_tweet.shape
# Out:
# (27396, 5)

# %%
#Lemmatize the text
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

def lemmatize_text(text):
  """Lemmatizes a text.

  Args:
    text: The text to lemmatize.

  Returns:
    The lemmatized text.
  """

  words = nltk.word_tokenize(text)
  lemmas = [nltk.WordNetLemmatizer().lemmatize(word) for word in words]
  return " ".join(lemmas)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
data_tweet['new_lemma_text'] = data_tweet["new_text"].apply(lemmatize_text)

# %%
data_tweet
# Out:
#           author_id      tweet_id  \
# 0      9.050000e+17  1.030258e+06
# 1      7.638583e+07  1.030186e+06
# 2      1.480000e+18  1.030263e+06
# 3      1.150000e+18  1.030274e+06
# 4      2.112887e+08  1.030288e+06
# ...             ...           ...
# 29798  1.480000e+18  1.683840e+18
# 29799  2.760856e+08  1.683940e+18
# 29800  1.104181e+08  1.683860e+18
# 29801  1.180000e+18  1.683920e+18
# 29802  4.867600e+08  1.683830e+18
#
#                                                     text          created_at  \
# 0      3 peaks Challenge #AxioActive💪\n\nOn the 12th ... 2023-07-28 08:18:00
# 1      Roche Drops Hemophilia A Candidate, Prepares f... 2023-07-27 15:51:00
# 2      Roche moves one Spark hemophilia gene therapy ... 2023-07-28 06:34:00
# 3      On #WorldHepatitisDay we put middle finger up ... 2023-07-28 00:27:00
# 4      One of our newest internship programs, launche... 2023-07-27 20:13:00
# ...                                                  ...                 ...
# 29798  Hear more from Mosi Williams, Pys.D, on the la... 2023-07-25 14:00:00
# 29799  Was discussing hemophilia with an intelligent,... 2023-07-25 20:32:00
# 29800  The affected &amp; infected have waited decade... 2023-07-25 15:25:00
# 29801  @MohmdBio Sickle cell anemia, Thalassemia, Hem... 2023-07-25 19:13:00
# 29802  Save the date to “tee up for a cure” on Monday... 2023-07-25 13:38:00
#
#                                                 new_text  \
# 0      peaks challenge axioactive on the th of august...
# 1      roche drops hemophilia a candidate prepares fo...
# 2      roche moves one spark hemophilia gene therapy ...
# 3      on worldhepatitisday we put middle finger up t...
# 4      one of our newest internship programs launched...
# ...                                                  ...
# 29798  hear more from mosi williams pys d on the late...
# 29799  was discussing hemophilia with an intelligent ...
# 29800  the affected amp infected have waited decades ...
# 29801          sickle cell anemia thalassemia hemophilia
# 29802  save the date to tee up for a cure on monday n...
#
#                                           new_lemma_text
# 0      peak challenge axioactive on the th of august ...
# 1      roche drop hemophilia a candidate prepares for...
# 2      roche move one spark hemophilia gene therapy i...
# 3      on worldhepatitisday we put middle finger up t...
# 4      one of our newest internship program launched ...
# ...                                                  ...
# 29798  hear more from mosi williams pys d on the late...
# 29799  wa discussing hemophilia with an intelligent e...
# 29800  the affected amp infected have waited decade f...
# 29801          sickle cell anemia thalassemia hemophilia
# 29802  save the date to tee up for a cure on monday n...
#
# [27396 rows x 6 columns]

# %% [markdown]
# # Topic Modelling:

# %%
#Extract embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Reduce dimensionality
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine',random_state=100)

# %%
#Cluster reduced embeddings
hdbscan_model = HDBSCAN(min_cluster_size=15,min_samples = 5, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# %%
# #Tokenize topics
# nltk.download('stopwords')
# stopwords = stopwords.words('english')
# vectorizer_model = CountVectorizer(stop_words= stopwords)

vectorizer_model = CountVectorizer(stop_words="english")

# %%
#Create topic representation
ctfidf_model = ClassTfidfTransformer()

# %%
from bertopic import BERTopic
from bertopic.representation import MaximalMarginalRelevance

representation_model = MaximalMarginalRelevance(diversity=0.3)

topic_model = BERTopic(
  embedding_model=embedding_model,    # Step 1 - Extract embeddings
  umap_model=umap_model,              # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,        # Step 3 - Cluster reduced embeddings
  vectorizer_model=vectorizer_model,  # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,          # Step 5 - Extract topic words
  representation_model=representation_model,
  nr_topics='auto',
  low_memory=True,
  n_gram_range=(1, 3),
  calculate_probabilities=True,
  verbose=True,
)

# %%
tweet_list = data_tweet.new_lemma_text.tolist()
timestamp=data_tweet.created_at.tolist()

# %%
topics, probs = topic_model.fit_transform(tweet_list)
# Out:
# 2024-01-31 07:35:51,634 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/857 [00:00<?, ?it/s]
# 2024-01-31 07:45:54,720 - BERTopic - Embedding - Completed ✓
# 2024-01-31 07:45:54,722 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-01-31 07:47:12,935 - BERTopic - Dimensionality - Completed ✓
# 2024-01-31 07:47:12,938 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-01-31 08:02:10,085 - BERTopic - Cluster - Completed ✓
# 2024-01-31 08:02:10,089 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-01-31 08:04:24,836 - BERTopic - Representation - Completed ✓
# 2024-01-31 08:04:24,841 - BERTopic - Topic reduction - Reducing number of topics
# 2024-01-31 08:04:30,505 - BERTopic - Topic reduction - Reduced number of topics from 657 to 20

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                              Name  \
# 0      -1   3938          -1_hemophilia_haemophilia_bleeding_blood
# 1       0  22839                0_hemophilia_haemophilia_day_blood
# 2       1    100            1_thanks_project_congratulation_lusher
# 3       2     76                         2_int_justin_yds_claypool
# 4       3     54                        3_gadfly_bolt_jackboot_jab
# 5       4     50                4_gunshot_bleeding_disorder_bullet
# 6       5     42           5_havana_conduction_oxidative_microwave
# 7       6     41  6_heart_migraine_polyneuropathy_thrombocytopenia
# 8       7     34                       7_tl_retweeted_bot_ethereum
# 9       8     26           8_scheme_maharashtra_transport_dailysis
# 10      9     24                       9_join_nhf_research_journal
# 11     10     22                  10_tattoo_weekend_secondlife_ear
# 12     11     22              11_tampon_unsanitary_sanitary_diaper
# 13     12     21                12_syndrome_genetic_heart_fibrosis
# 14     13     20                       13_pray_prayer_lupus_cancer
# 15     14     20   14_congratulation_heartiest_thosemostwriter_fem
# 16     15     18       15_gssy_spiritualsciencelab_heals_arthritis
# 17     16     17                   16_epf20_nmo_meeting_assessment
# 18     17     16                         17_forward_phew_pace_hell
# 19     18     16               18_nebraska_madison_foundation_lake
#
#                                        Representation  \
# 0   [hemophilia, haemophilia, bleeding, blood, tre...
# 1   [hemophilia, haemophilia, day, blood, treatmen...
# 2   [thanks, project, congratulation, lusher, staf...
# 3   [int, justin, yds, claypool, clutch, nfl, stol...
# 4   [gadfly, bolt, jackboot, jab, idealise, icepac...
# 5   [gunshot, bleeding, disorder, bullet, child, n...
# 6   [havana, conduction, oxidative, microwave, mel...
# 7   [heart, migraine, polyneuropathy, thrombocytop...
# 8   [tl, retweeted, bot, ethereum, uniswap, fortun...
# 9   [scheme, maharashtra, transport, dailysis, pos...
# 10  [join, nhf, research, journal, heavymenstrualb...
# 11  [tattoo, weekend, secondlife, ear, item, sale,...
# 12  [tampon, unsanitary, sanitary, diaper, kotex, ...
# 13  [syndrome, genetic, heart, fibrosis, vaccinati...
# 14  [pray, prayer, lupus, cancer, hurricaneian, ly...
# 15  [congratulation, heartiest, thosemostwriter, f...
# 16  [gssy, spiritualsciencelab, heals, arthritis, ...
# 17  [epf20, nmo, meeting, assessment, summit, heal...
# 18  [forward, phew, pace, hell, presenting, eating...
# 19  [nebraska, madison, foundation, lake, mix, con...
#
#                                   Representative_Docs
# 0   [today is world hemophilia day and this year t...
# 1   [hemophilia a, hemophilia, world hemophilia da...
# 2   [thank you for your support, thank you, thank ...
# 3   [justin field sophomore season is over let rev...
# 4   [kettle icecap jackboot gala haemorrhoid haemo...
# 5   [do those bleeding disorder include gunshot wo...
# 6   [dr beatrice golomb uc san diego medical cente...
# 7   [more than brand new pfizer pipeline will hit ...
# 8   [i can t believe no one is discussing this iss...
# 9   [shinde sarkar working for welfare of the peop...
# 10  [i m attending nhf s next research journal clu...
# 11  [new for manly weekend sale trippin out nexus ...
# 12  [is someone free bleeding their way through wa...
# 13  [with a genetic defect such a down syndrome kl...
# 14  [i ve had cancer x ask your husband to help pl...
# 15  [heartiest congratulation michael, i truly mis...
# 16  [benefit of gssy gt gssy heals cure or free th...
# 17  [a part of our visit we have assessment meetin...
# 18  [looking forward to seeing everyone again, loo...
# 19  [happy to support the nebraska chapter of the ...

# %% [markdown]
# # Let's check what are the words the first topic contains:

# %%
topic_model.get_topic(0)
# Out:
# [('hemophilia', 0.03637380276453562),
#  ('haemophilia', 0.02499117243543675),
#  ('day', 0.018956222516969327),
#  ('blood', 0.016527308823969515),
#  ('treatment', 0.01490818345231945),
#  ('disease', 0.011864343019727726),
#  ('worldhemophiliaday', 0.009836769858943273),
#  ('support', 0.009354638813969097),
#  ('health', 0.009041281326136774),
#  ('bleed', 0.008504089185093084)]

# %% [markdown]
# # Create a list of words under every topic

# %%
def get_bert_topics(topic_model, num_topics):
    word_dict = {}
    for i in range(num_topics):
        words=topic_model.get_topic(i)
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words]
    return pd.DataFrame(word_dict)

get_bert_topics(topic_model, len(set(topics))-1)
# Out:
#            Topic # 01      Topic # 02  Topic # 03           Topic # 04  \
# 0          hemophilia          thanks         int               gadfly
# 1         haemophilia         project      justin                 bolt
# 2                 day  congratulation         yds             jackboot
# 3               blood          lusher    claypool                  jab
# 4           treatment         staffer      clutch             idealise
# 5             disease             zro         nfl              icepack
# 6  worldhemophiliaday      polyhedron       stole             icecream
# 7             support          intern  montgomery    whenthroughstrong
# 8              health            cara       field                 ibis
# 9               bleed     stimulating  hemophilia  servicehimselfreach
#
#      Topic # 05  Topic # 06        Topic # 07      Topic # 08   Topic # 09  \
# 0       gunshot      havana             heart              tl       scheme
# 1      bleeding  conduction          migraine       retweeted  maharashtra
# 2      disorder   oxidative    polyneuropathy             bot    transport
# 3        bullet   microwave  thrombocytopenia        ethereum     dailysis
# 4         child   melatonin            immune         uniswap     positive
# 5           nra  ultrasound       scamcovid19         fortune       sarkar
# 6      provoked       aging            sickle         airdrop          hiv
# 7       wounded      cancer            pfizer         exploit      welfare
# 8       firearm     medical     demyelinating           claim     dialysis
# 9  gunreformnow  hemophilia           topline  oppofindn2flip   initiative
#
#                Topic # 10  Topic # 11  Topic # 12   Topic # 13    Topic # 14  \
# 0                    join      tattoo      tampon     syndrome          pray
# 1                     nhf     weekend  unsanitary      genetic        prayer
# 2                research  secondlife    sanitary        heart         lupus
# 3                 journal         ear      diaper     fibrosis        cancer
# 4  heavymenstrualbleeding        item       kotex  vaccination  hurricaneian
# 5       scholarlyresearch        sale     poverty       cystic      lymphoma
# 6                     mba       nexus     hygiene        toxin      pandemic
# 7                brussels         fav  disposable         mrna        broken
# 8                  mentor   piercings  fecephilia      symptom         house
# 9                  robert      grunge      vagina    hematuria       shelter
#
#         Topic # 15           Topic # 16         Topic # 17  Topic # 18  \
# 0   congratulation                 gssy              epf20     forward
# 1        heartiest  spiritualsciencelab                nmo        phew
# 2  thosemostwriter                heals            meeting        pace
# 3              fem            arthritis         assessment        hell
# 4          tribute               asthma             summit  presenting
# 5           lovely             diabetes     healthliteracy      eating
# 6          michael              benefit       futurehealth          ll
# 7              wow                 cure  patientengagement     journey
# 8      highlighted                  aid          dominican        miss
# 9            paper              disease               care        look
#
#    Topic # 19
# 0    nebraska
# 1     madison
# 2  foundation
# 3        lake
# 4         mix
# 5     contest
# 6      maryed
# 7  showcasing
# 8       judge
# 9   celebrity

# %% [markdown]
# # Model Visualization:

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="708f8733-72c8-434e-adbe-530d5f034515" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("708f8733-72c8-434e-adbe-530d5f034515")) {                    Plotly.newPlot(                        "708f8733-72c8-434e-adbe-530d5f034515",                        [{"customdata":[[0,"hemophilia | haemophilia | day | blood | treatment",22839],[1,"thanks | project | congratulation | lusher | staffer",100],[2,"int | justin | yds | claypool | clutch",76],[3,"gadfly | bolt | jackboot | jab | idealise",54],[4,"gunshot | bleeding | disorder | bullet | child",50],[5,"havana | conduction | oxidative | microwave | melatonin",42],[6,"heart | migraine | polyneuropathy | thrombocytopenia | immune",41],[7,"tl | retweeted | bot | ethereum | uniswap",34],[8,"scheme | maharashtra | transport | dailysis | positive",26],[9,"join | nhf | research | journal | heavymenstrualbleeding",24],[10,"tattoo | weekend | secondlife | ear | item",22],[11,"tampon | unsanitary | sanitary | diaper | kotex",22],[12,"syndrome | genetic | heart | fibrosis | vaccination",21],[13,"pray | prayer | lupus | cancer | hurricaneian",20],[14,"congratulation | heartiest | thosemostwriter | fem | tribute",20],[15,"gssy | spiritualsciencelab | heals | arthritis | asthma",18],[16,"epf20 | nmo | meeting | assessment | summit",17],[17,"forward | phew | pace | hell | presenting",16],[18,"nebraska | madison | foundation | lake | mix",16]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[22839,100,76,54,50,42,41,34,26,24,22,22,21,20,20,18,17,16,16],"sizemode":"area","sizeref":14.274375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[9.467508316040039,-9.756026268005371,8.452315330505371,-10.3056001663208,9.476147651672363,10.122715950012207,3.169039487838745,-9.973995208740234,-9.229718208312988,-9.465660095214844,9.335495948791504,9.85175895690918,2.887408971786499,8.736889839172363,-10.027630805969238,2.6827778816223145,-9.027536392211914,-10.879932403564453,10.3648099899292],"xaxis":"x","y":[9.756168365478516,12.884625434875488,11.540974617004395,13.188358306884766,10.092371940612793,9.963613510131836,4.489704132080078,13.366850852966309,11.606613159179688,12.24244213104248,10.408764839172363,10.923906326293945,4.219435214996338,10.489200592041016,12.723128318786621,4.024460315704346,11.8924560546875,12.829607963562012,10.441573143005371],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333 ...

# %%
topic_model.visualize_barchart(top_n_topics=10, n_words = 10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7f224948-e9e9-4174-9890-2c431bded5df" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f224948-e9e9-4174-9890-2c431bded5df")) {                    Plotly.newPlot(                        "7f224948-e9e9-4174-9890-2c431bded5df",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.008504089185093084,0.009041281326136774,0.009354638813969097,0.009836769858943273,0.011864343019727726,0.01490818345231945,0.016527308823969515,0.018956222516969327,0.02499117243543675,0.03637380276453562],"y":["bleed  ","health  ","support  ","worldhemophiliaday  ","disease  ","treatment  ","blood  ","day  ","haemophilia  ","hemophilia  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.05163572573050785,0.05163572573050785,0.05804486019521148,0.06069465604935516,0.06069465604935516,0.06069465604935516,0.06069465604935516,0.07495530348765664,0.14036304713081474,0.1882284587833292],"y":["stimulating  ","cara  ","intern  ","polyhedron  ","zro  ","staffer  ","lusher  ","congratulation  ","project  ","thanks  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02525333555574732,0.1841997612520145,0.21542350756231754,0.21542350756231754,0.21542350756231754,0.216888225773331,0.21738922183194376,0.21738922183194376,0.21738922183194376,0.21738922183194376],"y":["hemophilia  ","field  ","montgomery  ","stole  ","nfl  ","clutch  ","claypool  ","yds  ","justin  ","int  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.07198668508179333,0.07198668508179333,0.07198668508179333,0.07198668508179333,0.07198668508179333,0.07198668508179333,0.1048313033182746,0.13322833918902688,0.13322833918902688,0.1904152428766424],"y":["servicehimselfreach  ","ibis  ","whenthroughstrong  ","icecream  ","icepack  ","idealise  ","jab  ","jackboot  ","bolt  ","gadfly  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.04259762557592358,0.04259762557592358,0.04259762557592358,0.04259762557592358,0.04259762557592358,0.07092593236672894,0.07883695300635078,0.12015084602708453,0.13357514987536467,0.17608291610989096],"y":["gunreformnow  ","firearm  ","wounded  ","provoked  ","nra  ","child  ","bullet  ","disorder  ","bleeding  ","gunshot  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.023529558384706547,0.11516141777461514,0.13195811378295216,0.17972749214619138,0.20982339652943852,0.22374718634052623,0.22374718634052623,0.22374718634052623,0.22374718634052623,0.22374718634052623],"y":["hemophilia  ","medical  ","cancer  ","aging  ","ultrasound  ","melatonin  ","microwave  ","oxidative  ","conduction  ","havana  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.057886636323402414,0.08476893007295609,0.12063951774930716,0.131624170834291,0.14285098770551988,0.14947302941288595,0.18492336257157657,0.19649637678183524,0.21190507316417076,0.2707038252191859],"y":["topline  ","demyelinating  ","pfizer  ","sickle  ","scamcovid19  ","immune  ","thrombocytopenia  ","polyneuropathy  ","migraine  ","heart  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.041364286750785476,0.04140657766553411,0.0745668656080834,0.07655436862086623,0.12524778994192784,0.14076197838338889,0.17098474704657562,0.214687902035755,0.2526431721839081,0.2800034746550454],"y":["oppofindn2flip  ","claim  ","exploit  ","airdrop  ","fortune  ","uniswap  ","ethereum  ","bot  ","retweeted  ","tl  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"} ...

# %%
def create_wordcloud(topic_model, topic):
    text = {word: value for word, value in topic_model.get_topic(topic)}
    wc = WordCloud(background_color="white", max_words=1000)
    wc.generate_from_frequencies(text)
    plt.figure(figsize=(5, 4), dpi=150)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("On")
    plt.title("Representation of Topic"+" "+ str(topic))
    plt.show()

#visualize the top 10 topics
for i in range(0,11):
    create_wordcloud(topic_model, topic=i)

# %%
topic_model.visualize_heatmap(n_clusters = 10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="422bfe6a-4102-41d2-b450-29b4b36f9168" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("422bfe6a-4102-41d2-b450-29b4b36f9168")) {                    Plotly.newPlot(                        "422bfe6a-4102-41d2-b450-29b4b36f9168",                        [{"coloraxis":"coloraxis","name":"0","x":["0_hemophilia_haemophilia_day","13_pray_prayer_lupus","1_thanks_project_congratula...","3_gadfly_bolt_jackboot","9_join_nhf_research","14_congratulation_heartiest...","17_forward_phew_pace","2_int_justin_yds","4_gunshot_bleeding_disorder","11_tampon_unsanitary_sanitary","5_havana_conduction_oxidative","6_heart_migraine_polyneurop...","12_syndrome_genetic_heart","7_tl_retweeted_bot","8_scheme_maharashtra_transp...","15_gssy_spiritualsciencelab...","10_tattoo_weekend_secondlife","18_nebraska_madison_foundat...","16_epf20_nmo_meeting"],"y":["0_hemophilia_haemophilia_day","13_pray_prayer_lupus","1_thanks_project_congratula...","3_gadfly_bolt_jackboot","9_join_nhf_research","14_congratulation_heartiest...","17_forward_phew_pace","2_int_justin_yds","4_gunshot_bleeding_disorder","11_tampon_unsanitary_sanitary","5_havana_conduction_oxidative","6_heart_migraine_polyneurop...","12_syndrome_genetic_heart","7_tl_retweeted_bot","8_scheme_maharashtra_transp...","15_gssy_spiritualsciencelab...","10_tattoo_weekend_secondlife","18_nebraska_madison_foundat...","16_epf20_nmo_meeting"],"z":[[1.0000000000000004,0.4867918304324032,0.19764669503554472,0.20784706606810083,0.25482259466909685,0.18603553902016068,0.13590920645506788,0.21938564875995903,0.3984823815310288,0.3754098289239115,0.37945049121656316,0.5420601587872895,0.4901493157602048,0.11463291761274645,0.3660477612843751,0.29033364619424457,0.4662781896360279,0.4958221086627731,0.29723481249536843],[0.4867918304324032,1.0000000000000002,0.32671860575883294,0.2009405902522669,0.3642532794492128,0.26522354891161726,0.27264697560774365,0.08777165135544543,0.39506936512756685,0.1715135499609619,0.37289959421263486,0.3611529154310623,0.42021521599658995,0.17352211435381362,0.2786838940125507,0.282476466268598,0.32498801151417617,0.3222472213767936,0.35436845310699133],[0.19764669503554472,0.32671860575883294,0.9999999999999996,0.4952474950427215,0.690266247860092,0.7037117763352005,0.5949271863250865,0.10496921259385575,0.15517746024941828,0.10174019990072246,0.14921259940020584,0.06226258303991161,0.06028222998267235,0.39346851007731876,0.12841581280080172,0.10712838248924969,0.30764978471588966,0.27466163133564525,0.3734809739277757],[0.20784706606810083,0.2009405902522669,0.4952474950427215,1.0000000000000004,0.3196168877549602,0.41034933399079987,0.43447525157172384,0.12480666024346093,0.16430492777013617,0.21905545688860495,0.1234449040511588,0.1425286724535038,0.09094674257005164,0.28847824667771593,0.2080531253548362,0.14263799678102163,0.2843047481760152,0.29047799239292893,0.25878237638293133],[0.25482259466909685,0.3642532794492128,0.690266247860092,0.3196168877549602,1.0000000000000007,0.5374601588290082,0.4751214239235593,-0.04533917878991514,0.1143900956310985,0.11975467215235154,0.2788343195096761,0.06433813828039789,0.09969229520905193,0.3630048227371291,0.24430762801401443,0.17193766469535454,0.23474601285726687,0.28938545560612583,0.556533001777862],[0.18603553902016068,0.26522354891161726,0.7037117763352005,0.41034933399079987,0.5374601588290082,1.0000000000000002,0.423677902546164,0.18485572940657713,0.1297799244993042,0.09916705774214693,0.1642577073710649,0.12543849933185414,0.05698463104181447,0.3128394960606674,0.056832801410843736,0.045263965154479516,0.26876173254327773,0.2892577880269926,0.29372130265969737],[0.13590920645506788,0.27264697560774365,0.5949271863250865,0.4344 ...

# %% [markdown]
# ## let's do the similarity matrix for the top 10 topics

# %%
topic_model.visualize_heatmap(top_n_topics=10, n_clusters = 5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c472ced5-c627-4e22-9a07-e0ae4529fad8" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c472ced5-c627-4e22-9a07-e0ae4529fad8")) {                    Plotly.newPlot(                        "c472ced5-c627-4e22-9a07-e0ae4529fad8",                        [{"coloraxis":"coloraxis","name":"0","x":["0_hemophilia_haemophilia_day","6_heart_migraine_polyneurop...","8_scheme_maharashtra_transp...","1_thanks_project_congratula...","3_gadfly_bolt_jackboot","7_tl_retweeted_bot","9_join_nhf_research","2_int_justin_yds","4_gunshot_bleeding_disorder","5_havana_conduction_oxidative"],"y":["0_hemophilia_haemophilia_day","6_heart_migraine_polyneurop...","8_scheme_maharashtra_transp...","1_thanks_project_congratula...","3_gadfly_bolt_jackboot","7_tl_retweeted_bot","9_join_nhf_research","2_int_justin_yds","4_gunshot_bleeding_disorder","5_havana_conduction_oxidative"],"z":[[1.0000000000000004,0.5420601587872895,0.3660477612843751,0.19764669503554472,0.20784706606810083,0.11463291761274645,0.25482259466909685,0.21938564875995903,0.3984823815310288,0.37945049121656316],[0.5420601587872895,1.0000000000000004,0.316199828969658,0.06226258303991161,0.1425286724535038,0.15521326035004848,0.06433813828039789,0.1388780989378593,0.22029240339779255,0.2163417447374759],[0.3660477612843751,0.316199828969658,1.0000000000000002,0.12841581280080172,0.2080531253548362,0.20826902472332853,0.24430762801401443,-0.00924189115188284,0.11518897101991504,0.12979797319408104],[0.19764669503554472,0.06226258303991161,0.12841581280080172,0.9999999999999996,0.4952474950427215,0.39346851007731876,0.690266247860092,0.10496921259385575,0.15517746024941828,0.14921259940020584],[0.20784706606810083,0.1425286724535038,0.2080531253548362,0.4952474950427215,1.0000000000000004,0.28847824667771593,0.3196168877549602,0.12480666024346093,0.16430492777013617,0.1234449040511588],[0.11463291761274645,0.15521326035004848,0.20826902472332853,0.39346851007731876,0.28847824667771593,1.0000000000000013,0.3630048227371291,0.023744688715669413,0.02075048194681143,0.01520509016453569],[0.25482259466909685,0.06433813828039789,0.24430762801401443,0.690266247860092,0.3196168877549602,0.3630048227371291,1.0000000000000007,-0.04533917878991514,0.1143900956310985,0.2788343195096761],[0.21938564875995903,0.1388780989378593,-0.00924189115188284,0.10496921259385575,0.12480666024346093,0.023744688715669413,-0.04533917878991514,1.0000000000000004,0.12694736426111225,-0.0028320797270838718],[0.3984823815310288,0.22029240339779255,0.11518897101991504,0.15517746024941828,0.16430492777013617,0.02075048194681143,0.1143900956310985,0.12694736426111225,1.0000000000000007,0.18597192649402203],[0.37945049121656316,0.2163417447374759,0.12979797319408104,0.14921259940020584,0.1234449040511588,0.01520509016453569,0.2788343195096761,-0.0028320797270838718,0.18597192649402203,1.0000000000000004]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eSimilarity Score: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222222 ...

# %% [markdown]
# ## Topics over time calculation:

# %%
topics_over_time = topic_model.topics_over_time(tweet_list, timestamp, nr_bins=20)
topics_over_time
# Out:
# 19it [00:35,  1.85s/it]
#      Topic                                              Words  Frequency  \
# 0       -1        hemophilia, pwd, haemophilia, gene, disease        177
# 1        0  hemophilia, haemophilia, blood, bleeding, diso...        916
# 2        1  thanks, project, glad, congratulation, polyhedron          2
# 3        3              jab, jackboot, gait, gadget, jabbered          2
# 4        7            weekend, news, retweeted, bot, ethereum          2
# ..     ...                                                ...        ...
# 151     -1      bos, ukraine, hemophilia, haemophilia, gibson         64
# 152      0     hemophilia, haemophilia, blood, plz, treatment        426
# 153      7                 tl, retweeted, bot, ethereum, devs          2
# 154     10             tattoo, weekend, secondlife, ear, item          8
# 155     16       organisation, screening, epf20, nmo, meeting          1
#
#                   Timestamp
# 0   2023-01-01 15:54:58.860
# 1   2023-01-01 15:54:58.860
# 2   2023-01-01 15:54:58.860
# 3   2023-01-01 15:54:58.860
# 4   2023-01-01 15:54:58.860
# ..                      ...
# 151 2023-11-21 22:34:03.000
# 152 2023-11-21 22:34:03.000
# 153 2023-11-21 22:34:03.000
# 154 2023-11-21 22:34:03.000
# 155 2023-11-21 22:34:03.000
#
# [156 rows x 4 columns]

# %%
topic_model.visualize_topics_over_time(topics_over_time, title = '<b>Representation of Topics over Time</b>', top_n_topics=10,height = 450, width = 850)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="997edfd7-2abe-4982-a5dd-98d78ef4618e" class="plotly-graph-div" style="height:450px; width:850px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("997edfd7-2abe-4982-a5dd-98d78ef4618e")) {                    Plotly.newPlot(                        "997edfd7-2abe-4982-a5dd-98d78ef4618e",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, bleeding, disorder","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, treatment, factor","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, factor, blood, bleeding","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, fda, gene, treatment","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, treatment, factor","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, treatment, bleed","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, worldhemophiliaday, blood, care","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, help, treatment","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, bleeding, treatment","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, disease, wa","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, gene, fda, biomarin","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: work, hemophilia, apartment, medicine, joint","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, eahad2023, blood, treatment","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, iu, mystery, haemophilia, immune","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, gene, factor, blood","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, eahad2023, help, blood","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, family, bleed","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: nursesday, difference, haemophilia, patient, hemophilia","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, plz, treatment"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_hemophilia_haemophilia_day_blood","x":["2023-01-01T15:54:58.860000","2023-01-19T01:16:57","2023-02-05T02:27:54","2023-02-22T03:38:51","2023-03-11T04:49:48","2023-03-28T06:00:45","2023-04-14T07:11:42","2023-05-01T08:22:39","2023-05-18T09:33:36","2023-06-04T10:44:33","2023-06-21T11:55:30","2023-07-08T13:06:27","2023-07-25T14:17:24","2023-08-11T15:28:21","2023-08-28T16:39:18","2023-10-01T19:01:12","2023-10-18T20:12:09","2023-11-04T21:23:06","2023-11-21T22:34:03"],"y":[916,1810,1238,1724,1794,1172,5733,911,1662,257,745,1605,981,184,592,572,313,204,426],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: thanks, project, glad, congratulation, polyhedron","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: clemente, cara, joining, partner, advocacy","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: leadership, project, congratulation, lusher, staffer","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: exciting, project, glad, congratulation, zro","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: megan, thanks, polyhedron, zro, staffer","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: mark, glad, congratulation, polyhed ...

# %% [markdown]
# ## Here as we can see topic 0 has the peak for always compared to other topics. So that those topics over time graph is not that visible rather being congested with each other. Hence normalizing the frequency of the topics over time, so that all the frequency comes in between 0 to 1 and we get a better idea of the topics being discussed. The below diagram is showing normaized frequency.

# %%
topic_model.visualize_topics_over_time(topics_over_time, title = '<b>Representation of Topics over Time</b>', normalize_frequency= True, top_n_topics=10,height = 450, width = 850)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="44c170a4-8f2e-4ca1-a2e0-0a0c7d1ea84f" class="plotly-graph-div" style="height:450px; width:850px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44c170a4-8f2e-4ca1-a2e0-0a0c7d1ea84f")) {                    Plotly.newPlot(                        "44c170a4-8f2e-4ca1-a2e0-0a0c7d1ea84f",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, bleeding, disorder","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, treatment, factor","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, factor, blood, bleeding","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, fda, gene, treatment","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, treatment, factor","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, treatment, bleed","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, worldhemophiliaday, blood, care","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, help, treatment","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, bleeding, treatment","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, disease, wa","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, gene, fda, biomarin","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: work, hemophilia, apartment, medicine, joint","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, eahad2023, blood, treatment","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, iu, mystery, haemophilia, immune","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, gene, factor, blood","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, eahad2023, help, blood","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, family, bleed","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: nursesday, difference, haemophilia, patient, hemophilia","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hemophilia, haemophilia, blood, plz, treatment"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_hemophilia_haemophilia_day_blood","x":["2023-01-01T15:54:58.860000","2023-01-19T01:16:57","2023-02-05T02:27:54","2023-02-22T03:38:51","2023-03-11T04:49:48","2023-03-28T06:00:45","2023-04-14T07:11:42","2023-05-01T08:22:39","2023-05-18T09:33:36","2023-06-04T10:44:33","2023-06-21T11:55:30","2023-07-08T13:06:27","2023-07-25T14:17:24","2023-08-11T15:28:21","2023-08-28T16:39:18","2023-10-01T19:01:12","2023-10-18T20:12:09","2023-11-04T21:23:06","2023-11-21T22:34:03"],"y":[0.1236669977791185,0.2443638274893062,0.1671394576971056,0.23275317049257677,0.24220370525735654,0.1582289534903132,0.7739987972354655,0.12299195958163424,0.2243826968437718,0.03469696335069155,0.10058069142515642,0.2166872613924511,0.13244249434641403,0.024841405667421185,0.07992452258213772,0.07722436979220064,0.04225739116251539,0.02754155845735827,0.05751325442565992],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: thanks, project, glad, congratulation, polyhedron","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: clemente, cara, joining, partner, advocacy","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: leadership, project, congratulation, lusher, staffer","\u003cb\u003eT ...

# %%
docs = tweet_list

# %% [markdown]
# ## Visualize a hierarchical structure of the topics:

# %%
# Extract hierarchical topics and their representations
hierarchical_topics = topic_model.hierarchical_topics(docs)

# Visualize these representations
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 18/18 [00:04<00:00,  3.72it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4a535fa2-e5c5-4688-862f-25b9cad41234" class="plotly-graph-div" style="height:485px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a535fa2-e5c5-4688-862f-25b9cad41234")) {                    Plotly.newPlot(                        "4a535fa2-e5c5-4688-862f-25b9cad41234",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["scheme_maharashtra_transport_dailysis_positive","","","gssy_spiritualsciencelab_heals_arthritis_asthma"],"x":[0.0,0.9438167319937927,0.9438167319937927,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["syndrome_genetic_heart_fibrosis_vaccination","","","heart_migraine_polyneuropathy_thrombocytopenia_immune"],"x":[0.0,0.8470076972400729,0.8470076972400729,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["migraine_polyneuropathy_thrombocytopenia_syndrome_immune","","","pray_prayer_lupus_cancer_hurricaneian"],"x":[0.8470076972400729,0.9352622437447371,0.9352622437447371,0.0],"xaxis":"x","y":[-30.0,-30.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["scheme_gssy_maharashtra_transport_government","","","migraine_polyneuropathy_thrombocytopenia_syndrome_immune"],"x":[0.9438167319937927,1.0205660311355338,1.0205660311355338,0.9352622437447371],"xaxis":"x","y":[-10.0,-10.0,-37.5,-37.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["int_justin_yds_claypool_clutch","","","havana_conduction_oxidative_microwave_melatonin"],"x":[0.0,0.999440012805739,0.999440012805739,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["record_yds_sophomore_potato_claypool","","","gadfly_bolt_jackboot_jab_idealise"],"x":[0.999440012805739,1.0001865927253881,1.0001865927253881,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["nebraska_madison_foundation_lake_mix","","","tattoo_weekend_secondlife_ear_item"],"x":[0.0,0.9861062753522829,0.9861062753522829,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["tl_retweeted_bot_ethereum_uniswap","","","tattoo_weekend_mary_secondlife_lm"],"x":[0.0,0.9885342119214277,0.9885342119214277,0.9861062753522829],"xaxis":"x","y":[-85.0,-85.0,-100.0,-100.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["record_potato_yds_sophomore_justin","","","tattoo_bloody_weekend_tl_retweeted"],"x":[1.0001865927253881,1.009293254115433,1.009293254115433,0.9885342119214277],"xaxis":"x","y":[-67.5,-67.5,-92.5,-92.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","text":["gunshot_bleeding_disorder_bullet_child","","","hemophilia_haemophilia_day_blood_treatment"],"x":[0.0,0.7923493751592954,0.7923493751592954,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","text":["hemophilia_haemophilia_day_blood_treatment","","","epf20_nmo_meeting_assessment_summit"],"x":[0.7923493751592954,0.9437325063919729,0.9437325063919729,0.0],"xaxis":"x","y":[-120.0,-120.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb ...

# %% [markdown]
# # **MODEL VALIDATION**

# %%
# Preprocess Documents
documents = pd.DataFrame({"Document": docs,
                          "ID": range(len(docs)),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]

topic_words = [[words for words, _ in topic_model.get_topic(topic) if words!='']
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words,
                                 texts=tokens,
                                 corpus=corpus,
                                 dictionary=dictionary,
                                 coherence='c_v')
coherence = coherence_model.get_coherence()
print(coherence)
# Out:
# 0.7624180127089597
